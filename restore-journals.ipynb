# %%
from pymongo import MongoClient

# %%
mongo = MongoClient(
    "mongodb+srv://hamidovaslon1:nPxcKaGrRkAwxiek@cluster0.4w1m4jc.mongodb.net/?retryWrites=true&w=majority"   
)

# %%
import pandas as pd
activities=list(list(mongo["magazin"]["activities"].find()))
df = pd.DataFrame(
    data=list(list(mongo["magazin"]["activities"].find()))
).sort_values(by="date", ascending=True)
df
# Out:
#                            _id     user_id              action  \
# 215   686a757c28cd39427826c572       aslon      create_journal
# 186   686a758828cd39427826c574       aslon      create_journal
# 216   686a79c167136bc57831a523       aslon       login_success
# 0     686a79c667136bc57831a524       aslon       login_success
# 73    686a8cc167136bc57831a525  jaloliddin       login_success
# ...                        ...         ...                 ...
# 6304  6a1b074110b6126747f91390       umidx  create_transaction
# 6305  6a1b07ec10b6126747f91391       umidx  create_transaction
# 6306  6a1b083c10b6126747f91392       umidx       close_journal
# 6307  6a1bc84f5356e2d87e322a02       umidx      create_journal
# 6308  6a1bc8635356e2d87e322a03       umidx  create_transaction
#
#                                                    data           ip  \
# 215   {'branchnameorid': 'aadee444-306d-48e1-aa5c-50...   172.18.0.1
# ...

# %%
df[df["action"] == "create_journal" ]["data"].values
# Out:
# array([{'branchnameorid': 'aadee444-306d-48e1-aa5c-501b86a584be', 'date': datetime.datetime(2025, 7, 6, 0, 0)},
#        {'branchnameorid': 'aadee444-306d-48e1-aa5c-501b86a584be', 'date': datetime.datetime(2025, 7, 7, 0, 0)},
#        {'branchnameorid': '2dbbbb13-60be-425e-b07c-fa4889f0400d', 'date': datetime.datetime(2025, 7, 7, 0, 0)},
#        {'branchnameorid': 'aadee444-306d-48e1-aa5c-501b86a584be', 'date': datetime.datetime(2025, 7, 7, 0, 0)},
#        {'branchnameorid': '2dbbbb13-60be-425e-b07c-fa4889f0400d', 'date': datetime.datetime(2025, 7, 7, 0, 0)},
#        {'branchnameorid': 'aadee444-306d-48e1-aa5c-501b86a584be', 'date': datetime.datetime(2025, 7, 8, 0, 0)},
#        {'branchnameorid': '2dbbbb13-60be-425e-b07c-fa4889f0400d', 'date': datetime.datetime(2025, 7, 8, 0, 0)},
#        {'branchnameorid': 'aadee444-306d-48e1-aa5c-501b86a584be', 'date': datetime.datetime(2025, 7, 9, 0, 0)},
# ...

# %%
mongo["magazin"]['finance'].insert_many(
    [
{
  "finance": {
    "balance": {
      "cash": 143000000,
      "bank": 56500000,
      "terminal": 2000000,
      "mobile_apps": 1705000
    },
    "total_income": 0,
    "total_expenses": 0,
    "debt": 29500000
  },
  "suppliers": [
    "0cb250aa-14e5-4b64-97a3-85541c2baa41",
    "6010a885-181f-4267-8600-546956f2f1c3",
    "e0fa072d-4903-4f05-8a4f-94b3f25a29d1"
  ],
  "branch_id": "aadee444-306d-48e1-aa5c-501b86a584be",
  "branch_name": "Xonobod",
  "details": {
    "location": "Location A"
  },
  "total": -1000000
},
{
  "finance": {
    "balance": {
      "cash": 0,
      "bank": 0,
      "terminal": 0,
      "mobile_apps": 0
    },
    "total_income": 0,
    "total_expenses": 0,
    "debt": 0
  },
  "suppliers": [
    "a16f2521-6dde-4b39-8985-8ebd9b36b171",
    "50c20e0b-6243-486e-952f-84e5581429d3"
  ],
  "branch_id": "2dbbbb13-60be-425e-b07c-fa4889f0400d",
  "branch_name": "Polevoy",
  "details": {
    "location": "Location B"
  }
}
    ]
)
# Out:
# InsertManyResult([ObjectId('6a1be907e39f29b3dbc8eb88'), ObjectId('6a1be907e39f29b3dbc8eb89')], acknowledged=True)

# %%
transactions["user_id"].value_counts()
# Out:
# user_id
# asadx         1744
# umidx         1261
# saloh          388
# jaloliddin     383
# aslon          235
# dostonyh        30
# Name: count, dtype: int64

# %%
# create transactions
transactions = df[df["action"] == "create_transaction"]
transactions["data"].values
# Out:
# array([{'transactionbase': {'amount': 50000, 'description': 'Click ', 'type': 'credit', 'payment_method': 'cash'}, 'supplier_transaction': False, 'supplier_id': ''},
#        {'transactionbase': {'amount': 270000, 'description': 'Click ', 'type': 'credit', 'payment_method': 'cash'}, 'supplier_transaction': False, 'supplier_id': ''},
#        {'transactionbase': {'amount': 140000, 'description': 'Click ', 'type': 'credit', 'payment_method': 'cash'}, 'supplier_transaction': False, 'supplier_id': ''},
#        ...,
#        {'transactionbase': {'amount': 1200000, 'description': 'Click ', 'type': 'credit', 'payment_method': 'cash'}, 'supplier_transaction': False, 'supplier_id': ''},
#        {'transactionbase': {'amount': 1200000, 'description': 'Selsil firmaga ', 'type': 'credit', 'payment_method': 'cash'}, 'supplier_transaction': False, 'supplier_id': ''},
# ...

# %%
df[df["action"] == "close_journal"]["data"].values
# Out:
# array([{'journal_id': '6869fbfd45fa4aec21b5a847', 'cash_left': '1000', 'terminal_income': '1000'},
#        {'journal_id': '6869fbfd45fa4aec21b5a847', 'cash_left': '1000', 'terminal_income': '1000'},
#        {'cash_left': '1000', 'terminal_income': '1000', 'journal_id': '6869fbfd45fa4aec21b5a847'},
#        {'journal_id': '6869fbfd45fa4aec21b5a847', 'cash_left': '1000', 'terminal_income': '1000'},
#        {'cash_left': '6250000', 'terminal_income': '2200000', 'journal_id': '6869fbfd45fa4aec21b5a847'},
#        {'cash_left': '5700000', 'terminal_income': '3100000', 'journal_id': '6869fbfd45fa4aec21b5a847'},
#        {'journal_id': '686a214245fa4aec21b5a848', 'cash_left': '6250000', 'terminal_income': '2200000'},
#        {'cash_left': '8790000', 'terminal_income': '2200000', 'journal_id': '686a214245fa4aec21b5a848'},
#        {'journal_id': '6868f7b545fa4aec21b5a845', 'cash_left': '1000', 'terminal_income': '1000'},
# ...

# %%
df = df.drop(columns=["_id"])

# %%
# Out:
#          user_id              action  \
# 215        aslon      create_journal
# 186        aslon      create_journal
# 216        aslon       login_success
# 0          aslon       login_success
# 73    jaloliddin       login_success
# ...          ...                 ...
# 6304       umidx  create_transaction
# 6305       umidx  create_transaction
# 6306       umidx       close_journal
# 6307       umidx      create_journal
# 6308       umidx  create_transaction
#
#                                                    data           ip  \
# 215   {'branchnameorid': 'aadee444-306d-48e1-aa5c-50...   172.18.0.1
# 186   {'branchnameorid': 'aadee444-306d-48e1-aa5c-50...   172.18.0.1
# 216                       {'error': 'Invalid password'}   172.18.0.1
# 0                         {'error': 'Invalid password'}   172.18.0.1
# 73                        {'error': 'Invalid password'}   172.18.0.1
# ...                                                 ...          ...
# ...

# %%
df.to_json(
    "activities.jsonl", 
    orient="records", 
    lines=True
2)
# Out:
# /var/folders/3z/114t1ckn7y18rzrz_m6kfkt80000gn/T/ipykernel_65755/1100017637.py:1: Pandas4Warning: The default 'epoch' date format is deprecated and will be removed in a future version, please use 'iso' date format instead.
#   df.to_json(
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df.to_json(
#       2     "activities.jsonl",
#       3     orient="records",
#       4     lines=True
#
# File ~/Desktop/code/magazin/pos/.venv/lib/python3.13/site-packages/pandas/core/generic.py:2635, in NDFrame.to_json(self, path_or_buf, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index, indent, storage_options, mode)
#    2631
#    2632         config.is_nonnegative_int(indent)
#    2633         indent = indent or 0
#    2634
# -> 2635         return json.to_json(
# ...
